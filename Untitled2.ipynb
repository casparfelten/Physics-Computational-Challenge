# %%
print("testrun")
# Out:
# testrun

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re as re
print("Sucess")
# Out:
# Sucess

# %%
df=pd.DataFrame
# Out:
# Sucess

# %%
#spectra of air. Syntax is intensity:wavelength

# %%
#strong lines of nitrogen in air. Emission of nitrogen, with wavelength in air.
nitrogen_spectra_air = {
3955.85: 20,
3995.00: 50,
4041.31:30,
4241.78:20,
4447.03:30,
4601.48:30,
4607.16:20,
4621.39:20,
4630.54:40,
4643.08:30,
4803.29:20,
4963.98:80,
4994.36:20,
5001.48:30,
5005.15:40,
5007.32:30,
5010.62:20,
5045.10:30,
5666.63:30,
5676.02:30,
5679.56:40,
5686.21:20,
5710.77:20,
5752.50:150,
5931.78:30,
5941.65:30,
6482.05:40,
6482.70:90,
6610.56:40,
7423.64:150,
7442.29:200,
7468.31:200,
8184.87:90,
8188.02:90,
8216.34:140,
8223.14:90,
8242.39:90,
8438.74:30,
8567.74:120,
8594.00:140,
8629.24:150,
8655.89:120,
8680.28:150,
8683.4:150,
8686.15:120,
8703.25:120,
8711.70:140,
8718.83:120,
9386.8:120,
9392.79:140,
10112.48:80,
10114.64:90,
12186.82:90,
12469.62:200,
13429.61:120,
13581.33:201
              }

nitrogen_spectra_air_wavelength = nitrogen_spectra_air.keys
nitrogen_spectra_air_intensity = nitrogen_spectra_air.values

# %%
plt.stem(list(nitrogen_spectra_air_wavelength()), list(nitrogen_spectra_air_intensity()))
# Out:
# <StemContainer object of 3 artists>

# %%
carbon_spectra_air = {
2478.561:400,
2836.71:500,
2837.603:400,
2992.618:400,
3918.978:300,
3920.693:400,
4267.003:400,
4267.258:500,
5145.16:300,
5151.09:200,
5380.34:150,
5889.77:300,
6013.22:150,
6578.05:400,
6582.88:300,
7231.32:400,
7236.42:500,
8335.15:250,
9094.83:220,
9111.80:150,
9405.73:400,
9658.44:150,
10691.25:150,
11748.22:90,
11753.32:140,
11754.76:110,
16890.38:50,
}

carbon_spectra_air_wavelength = carbon_spectra_air.keys
carbon_spectra_air_intensity = carbon_spectra_air.values

# %%
plt.stem(list(carbon_spectra_air_wavelength()), list(carbon_spectra_air_intensity()))
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stem(list(nitrogen_spectra_air_wavelength()), list(nitrogen_spectra_air_intensity()))
# Out:
# <StemContainer object of 3 artists>

# %%
#NOTE ON SCATTERING: if scattered a lot, is more likely to hit outside of atmosphere at critical angle (total internal reflection)
# Thus, stays within the atmosphere. Smaller wavelengths are more likely to scatter, and thus are kept in the atmosphere. 
#Infrared scatters less, as a longer wavelength. Co2
